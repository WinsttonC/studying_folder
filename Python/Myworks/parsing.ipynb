# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd


URL_TEMPLATE = "https://www.work.ua/ru/jobs-odesa/?page=2"
r = requests.get(URL_TEMPLATE)


print(r.text)
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#" xml:lang="ru" lang="ru">
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
#     <meta name="Keywords" content="работа в киеве, работа, работа в украине, вакансии, резюме, поиск работы, ищу работу, работодатели, подбор персонала, work ua, ворк юа">
#     <meta name="Description" content="7272 вакансии в Одессе на Work.ua. Найти работу в Одессе теперь просто. Поиск вакансий по запросу, категориям, рассылка новых вакансий. Работа в Одессе на Work.ua найдется.">
#     <meta http-equiv="content-language" content="ru">
#
#     <meta http-equiv="Pragma" content="no-cache">
#     <meta http-equiv="no-cache">
#     <meta http-equiv="Expires" content="-1">
#     <meta http-equiv="Cache-Control" content="no-cache">
#     <meta name = "format-detection" content = "telephone=no">
#
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0">
#
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <meta name="theme-color" content="#ffffff">
#
#     <meta name="twitter:card" content="summary_large_image">
#     <meta name="twitter:site" content="@workuamedia">
#
#     <meta property="og:url" content="https://www.work.ua/jobs-odesa/">
#     <meta property="og:title" content="Работа в Одессе">
#     <meta property="og:description" content="Поиск по запросу, подбор вакансий по параметрам и рассылка свежих вакансий.">
#     <meta property="og:image" content="https://st.work.ua/i/og/workua-logo.png">
#     <meta property="og:type" content="article">
#             <meta property="og:image:width" content="1200">
#         <meta property="og:image:height" content="630">
#
#             <meta property="og:locale" content="ru_RU">
#                     <meta property="og:locale:alternate" content="uk_UA">
#                     <meta property="og:locale:alternate" content="en_US">
#                 <meta name="msapplication-config" content="//st.work.ua/browser/ie/browserconfig.xml?v2=1">
#
#     <title>Работа в Одессе. Вакансии в Одессе — Work.ua</title>
#
#     <script>
# dataLayer=[{userType:'jobseeker',ourJobseeker:'no'}];
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;
# f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-W6CVFN');
# </script>
#
#     <link rel="shortcut icon" href="//st.work.ua/browser/favicon.ico?v2=1">
#     <link rel="apple-touch-icon" sizes="60x60" href="//st.work.ua/browser/safari/apple-touch-icon-60x60.png?v=1">
#     <link rel="apple-touch-icon" sizes="76x76" href="//st.work.ua/browser/safari/apple-touch-icon-76x76.png?v=1">
#     <link rel="apple-touch-icon" sizes="120x120" href="//st.work.ua/browser/safari/apple-touch-icon-120x120.png?v=1">
#     <link rel="apple-touch-icon" sizes="152x152" href="//st.work.ua/browser/safari/apple-touch-icon-152x152.png?v=1">
#     <link rel="apple-touch-icon" sizes="167x167" href="//st.work.ua/browser/safari/apple-touch-icon-167x167.png?v=1">
#     <link rel="apple-touch-icon" sizes="180x180" href="//st.work.ua/browser/safari/apple-touch-icon-180x180.png?v=1">
#     <link rel="mask-icon" href="//st.work.ua/browser/safari/website_icon.svg?v2=1" color="#00a1f1">
#     <link rel="yandex-tableau-widget" href="//st.work.ua/browser/yandex-tableau/manifest.json?v2=11">
#
#
#                         <style>@font-face{font-display:block;font-family:glyphicons-work;src:url(//st.work.ua/fonts/glyphicons-work/glyphicons-work1.eot?v=39);src:url(//st.work.ua/fonts/glyphicons-work/glyphicons-work1.eot?v=39#iefix) format('embedded-opentype'),url(//st.work.ua/fonts/glyphicons-work/glyphicons-work1.woff?v=39) format('woff'),url(//st.work.ua/fonts/glyphicons-work/glyphicons-work1.ttf?v=39) format('truetype'),url(//st.work.ua/fonts/glyphicons-work/glyphicons-work1.svg?v=39#glyphicons-work) format('svg')}.glyphicon{position:relative;top:3px;display:inline-block;font-family:glyphicons-work;font-style:normal;font-weight:400;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.glyphicon-add:before{content:"\2295"}.glyphicon-angle:before{content:"\221f"}.glyphicon-bag:before{content:"\1f45c"}.glyphicon-board:before{content:"\2691"}.glyphicon-business:before{content:"\2647"}.glyphicon-chevron-down:before{content:"\e259"}.glyphicon-chevron-left:before{content:"\e257"}.glyphicon-chevron-right:before{content:"\e258"}.glyphicon-chevron-up:before{content:"\e260"}.glyphicon-circle:before{content:"\2022"}.glyphicon-cog:before{content:"\2699"}.glyphicon-comment:before{content:"\30aa"}.glyphicon-company:before{content:"\2645"}.glyphicon-confirmed:before{content:"\2646"}.glyphicon-copy:before{content:"\30b3"}.glyphicon-disability:before{content:"\267f"}.glyphicon-eye:before{content:"\1f441"}.glyphicon-fountain-pen:before{content:"\2710"}.glyphicon-facebook:before{content:"\3075"}.glyphicon-geolocation:before{content:"\1f4cd"}.glyphicon-home:before{content:"\1f3e0"}.glyphicon-info-sign:before{content:"\e086"}.glyphicon-key:before{content:"\1f511"}.glyphicon-lock:before{content:"\e033"}.glyphicon-man:before{content:"\2642"}.glyphicon-map-marker:before{content:"\e062"}.glyphicon-minus:before{content:"\2212"}.glyphicon-paperclip:before{content:"\30a4"}.glyphicon-pencil:before{content:"\270f"}.glyphicon-re:before{content:"\f112"}.glyphicon-remove:before{content:"\e014"}.glyphicon-search:before{content:"\e003"}.glyphicon-shopping-cart:before{content:"\30d0"}.glyphicon-star:before{content:"\2605"}.glyphicon-tick:before{content:"\2713"}.glyphicon-time:before{content:"\30c1"}.glyphicon-twitter:before{content:"\30c6"}.glyphicon-youtube:before{content:"\30a6"}.glyphicon-vip:before{content:"\a0e5"}.glyphicon-warning-sign:before{content:"\2644"}.glyphicon-white-heart:before{content:"\2661"}.glyphicon-woman:before{content:"\2640"}.glyphicon-heart:before{content:"\2764"}.glyphicon-phone-confirm:before{content:"\1f4de"}.glyphicon-lightning:before{content:"\26a1"}.glyphicon-branding:before{content:"\1f451"}.glyphicon-lightning-full:before{content:"\1f5f2"}.glyphicon-instagram:before{content:"\1f4f7"}.glyphicon-linkedin:before{content:"\69"}.glyphicon-star-half:before{content:"\2bea"}.glyphicon-star-outline:before{content:"\2606"}.glyphicon-stop:before{content:"\26d4"}.glyphicon-big-crown:before{content:"\265a"}.glyphicon-phone:before{content:"\2706"}.glyphicon-plus:before{content:"\2795"}.glyphicon-photocam:before{content:"\30dd"}.glyphicon-employees:before{content:"\1f464"}.glyphicon-globe:before{content:"\1f30d"}.glyphicon-hryvnia:before{content:"\20b4"}.glyphicon-menu:before{content:"\22ee"}.glyphicon-videocam:before{content:"\1f4f9"}.glyphicon-transition:before{content:"\238b"}.glyphicon-remote:before{content:"\238c"}.glyphicon-notifications:before{content:"\3310"}.glyphicon-filters:before{content:"\2261"}.glyphicon-sort:before{content:"\21f5"}.glyphicon-cached:before{content:"\1f504"}.glyphicon-bust:before{content:"\1f466"}.glyphicon-bust-circle:before{content:"\1f465"}.glyphicon-resume:before{content:"\e900"}.trn-info-block{border-left:2px solid #fa7900}.trn-info-block a{background:url(//st.work.ua/i/trn/logo.png) 20px 20px no-repeat;border:2px solid #fff;border-left:none;color:#6b7886!important;display:block;font-size:15px;padding:50px 20px 20px}.trn-info-block a:hover{text-decoration:none}.trn-info-block ...
#
#
# <link rel="canonical" href="https://www.work.ua/ru/jobs-odesa/" />
# <link rel="alternate" hreflang="uk" href="https://www.work.ua/jobs-odesa/" />
# <link rel="alternate" hreflang="ru" href="https://www.work.ua/ru/jobs-odesa/" />
# <link rel="alternate" hreflang="en" href="https://www.work.ua/en/jobs-odesa/" />
#
# </head>
# <body data-target="#sidenav-spy" data-spy="scroll">
#
#
#
#
# <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-W6CVFN" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#
# <header class="header-default hidden-print">
#                     <div class="container">
#                                                 <div class="link-section clearfix">
# <a href="/ru/employer/" class="pull-right text-opacity">
# Работодателю<span class="glyphicon glyphicon-chevron-right"></span>
# </a>
# <div class="dropdown pull-right">
# <a id="dropdownMenu100-2"
#    href="javascript:void(0)"
#    role="button"
#    data-toggle="dropdown"
#    aria-expanded="true"
#    class="dropdown-toggle text-opacity"
# >
# Русский<span class="glyphicon glyphicon-chevron-down glyph-indent"></span>
# </a>
# <ul class="dropdown-menu" id="header-language-switcher-list" role="menu" aria-labelledby="dropdownMenu100-2">
#                             <li data-locale="ua"
#                     data-locale-active="ru"
#                                     >
#                     <a href="https://www.work.ua/jobs-odesa/?setlp=ua&amp;page=2">Українська</a>
#                 </li>
#                             <li data-locale="ru"
#                     data-locale-active="ru"
#                     class="active"                >
#                     <a href="https://www.work.ua/ru/jobs-odesa/?&amp;page=2">Русский</a>
#                 </li>
#                             <li data-locale="en"
#                     data-locale-active="ru"
#                                     >
#                     <a href="https://www.work.ua/en/jobs-odesa/?setlp=en&amp;page=2">English</a>
#                 </li>
#             </ul>
# </div>
# </div>        </div>
#
#                     <nav class="navbar navbar-default">
#                 <div class="container">
#                     <div class="navbar-header">
#                         <a href="/ru/" id="logo"></a>
#                     </div>
#                     <ul class="nav navbar-nav">
#                                                     <li class="active">
#                                 <a href="/ru/jobs/" id="jobsSearch"><span class="glyphicon glyphicon-search"></span><span class="hidden-xs">Найти&nbsp;</span><span class="text-capitalize-xs block-xs">вакансии</span></a>
#                             </li>
#                                                             <li class=" ">
#                                     <a href="/ru/jobseeker/my/resumes/create/?step=card" id="resumeCreate"><span class="glyphicon glyphicon-add"></span><span class="hidden-xs">Разместить&nbsp;</span><span class="text-lowercase-md block-xs">Резюме</span></a>
#                                 </li>
#                                                                                                         <li><a class="visible-xs-block" href="/ru/jobseeker/login/" id="loginButton"><span class="glyphicon glyphicon-lock"></span><span class="visible-xs-block">Войти</span></a><a class="btn btn-default hidden-xs" href="/ru/jobseeker/login/" id="loginIcon">Войти</a></li>
#                                             </ul>
#                 </div>
#             </nav>
#
#
#     <section class="header-info header-info-limited">
#     <form id="searchform" action="/ru/jobs/">
#         <div class="container">
#             <hr>
#             <div id="city-header">
#
#
#             </div>
#
#             <div class="form-group clearfix cut-top">
#                 <div class="input-holder input-search-job">
#                     <input type="text" value="" class="form-control jobseeker-search" id="search" name="search" placeholder="Запрос" autocomplete="off">
#                     <div class="icon-stack">
#                         <a href="javascript:;" class="link-close hidden" tabindex="-1"><span class="glyphicon glyphicon-remove"></span></a>
#                     </div>
#                     <div id="resumename-holder">
#                     </div>
#                 </div>
#
#                 <div class="input-holder input-search-city">
#                     <input type="text" autocomplete="off" value="Одесса" placeholder="Город" class="js-main-region form-control" id="city">
#                     <div class="icon-stack">
#                         <a href="javascript:;" class="link-close js-region-reset hidden" tabindex="-1"><span class="glyphicon glyphicon-remove"></span></a>
#                     </div>
#                     <input type="hidden" class="js-rvalue" id="city-id" name="region" tabindex="-1" value="46">
#                 </div>
#
#                 <button type="submit" id="sm-but" value="Найти вакансии" class="btn btn-search btn-icon-loop"><span class="hidden-xs">Найти </span><span class="glyphicon glyphicon-search visible-xs-inline"></span></button>
#                 <p class="pull-right"><a href="javascript:;" class="text-opacity border-dashed" id="adv-search">Расширенный поиск</a></p>
#             </div>
#         </div>
#
#         <input type="hidden" name="advs" id="advs" value="0">
#         <input type="hidden" name="category" id="category" value="">
#         <input type="hidden" name="employment" id="employment" value="">
#         <input type="hidden" name="salaryfrom" id="salaryfrom" value="">
#         <input type="hidden" name="salaryto" id="salaryto" value="">
#         <input type="hidden" name="nosalary" id="nosalary" value="">
#         <input type="hidden" name="education" id="education" value="">
#         <input type="hidden" name="experience" id="experience" value="">
#         <input type="hidden" name="student" id="student" value="">
#         <input type="hidden" name="noresume" id="noresume" value="">
#         <input type="hidden" name="disability" id="disability" value="">
#         <input type="hidden" name="anyword" id="anyword" value="">
#         <input type="hidden" name="notitle" id="notitle" value="">
#         <input type="hidden" name="nosynonym" id="nosynonym" value="">
#         <input type="hidden" name="sort" id="sort" value="">
#         <input type="hidden" name="days" id="days" value="125">
#
#         </form>
# </section>
# </header>
#
#
#
#
#
# <section id="center" class="main-center bg-gray">
#
#     <div class="container" id="pjax">
#
# <div class="clearfix h-20"></div>
#
#
# <input type="hidden" id="city-helper" value="Одесса">
# <input type="hidden" id="city-id-helper" value="46">
#
# <div class="hidden" id="city-header-helper">
#
#
# </div>
#
# <div class="row">
# <div class="col-md-8 col-left">
#
#
#
#
# <div class="disconnect-alert hidden-md hidden-lg">
# <div class="alert alert-warning text-center add-top">
# <p><span class="glyphicon glyphicon-warning-sign text-warning"></span></p>
# <p>Кажется, у вас пропал интернет.<br>Все опять заработает, как только он появится.</p>
# </div>
# </div><div class="pick-full-load">
# <img width="200" height="100" src="https://i.work.ua/employer_design/5/4/5/711545_company_logo_2.png" alt="">
# <img width="200" height="100" src="https://i.work.ua/employer_design/0/3/7/85037_company_logo_1.png" alt="">
# <img width="200" height="100" src="https://i.work.ua/employer_design/5/5/0/1851550_company_logo_1.png" alt="">
# <img width="200" height="100" src="https://i.work.ua/employer_design/7/5/1/21751_company_logo_3.png" alt="">
# <img width="200" height="100" src="https://i.work.ua/employer_design/7/5/1/21751_company_logo_3.png" alt="">
# <img width="200" height="100" src="https://i.work.ua/employer_design/8/3/9/574839_company_logo_1.png" alt="">
# <img width="200" height="100" src="https://i.work.ua/employer_design/9/4/3/23943_company_logo_3.png" alt="">
# <img width="200" height="100" src="https://i.work.ua/employer_design/2/3/6/544236_company_logo_2.png" alt="">
# <img width="200" height="100" src="https://i.work.ua/employer_design/9/4/3/23943_company_logo_3.png" alt="">
# <img width="200" height="100" src="https://i.work.ua/employer_design/9/4/3/23943_company_logo_3.png" alt="">
# </div>
#
# <div class="card">
# <div class="add-top">7272 вакансии</div>
# <div class="filter-column-2">
# <div class="filter-column-first">
# <h1 class="text-basic text-muted">
# Одесса
# <span class="dropdown">
# <a href="javascript:;" class="dropdown-toggle nowrap" role="button" id="dropdownMenu1" data-toggle="dropdown" aria-expanded="true">
# за 30 дней<span class="glyphicon glyphicon-chevron-down glyph-indent"></span>
# </a>
# <ul class="dropdown-menu" role="menu">
# <li class="active">
# <a href="/ru/jobs-odesa/?days=125" class=days data-days="125">за 30 дней</a>
# </li>
# <li >
# <a href="/ru/jobs-odesa/?days=124" class=days data-days="124">за 14 дней</a>
# </li>
# <li >
# <a href="/ru/jobs-odesa/?days=123" class=days data-days="123">за 7 дней</a>
# </li>
# <li >
# <a href="/ru/jobs-odesa/?days=122" class=days data-days="122">за 1 день</a>
# </li>
# </ul>
# </span>
# </h1>
# </div>
# <div class="filter-column-second">
# <div class="text-muted">Сортировка: </div>
# <div class="dropdown no-pull-xs">
#
# <a href="javascript:;" class="dropdown-toggle nowrap" role="button" id="dropdownMenu2" data-toggle="dropdown" aria-expanded="true">
# по дате<span class="glyphicon glyphicon-chevron-down glyph-indent"></span>
# </a>
#
# <ul class="dropdown-menu pull-right" role="menu">
# <li class="active"><a class=sort href="/ru/jobs-odesa/" data-sort="">По дате</a></li>
# <li class=""><a class=sort href="/ru/jobs-odesa/?sort=salary" data-sort="salary">По зарплате</a></li>
# <li class="">
# <a id="distanceSortLink" class=sort href="/ru/jobs-odesa/?sort=distance" data-sort="distance">По удаленности</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
#
# <div id="pjax-job-list">
#
#
#
#
#
# <a name="4458206"></a>
# <div class="card card-hover card-visited wordwrap job-link js-hot-block">
#
#
#
# <img width="100" height="50" alt="Amazon Partner Company"
#  class="preview-img preview-img-logo"
#  src="https://i.work.ua/employer_design/5/4/5/711545_company_logo_2.png">
#
# <h2 class="">
# <a href="/ru/jobs/4458206/" title="Программист (Senior PHP), Team Lead, вакансия от 20 июля 2021">Программист (Senior PHP), Team Lead</a>
# </h2>
#             <div>
#                             <b>54&#8239;000&thinsp;–&thinsp;90&#8239;000&nbsp;грн</b>&nbsp;<span class="text-muted">·</span>&#32;<span class="text-muted">Пробний термін до 3 місяців</span></div>
#
# <div class="add-top-xs">
#
# <span><b>Amazon Partner Company</b></span>&nbsp;<span>·</span>&#32;<span>Одесса</span>&#32;</div>
#
#     <p class="overflow text-muted add-top-sm add-bottom">
#             Полная занятость, удаленная работа. Опыт работы от 2 лет.<br>
#                             Вимоги:   PHP ООП Розробка та підтримка високонавантажених систем, роботів, парсеров. PHP v5.6 8.0, native&hellip;&#8288;<a href="/ru/jobs/4458206/" class="no-decoration"><span class="glyphicon glyphicon-chevron-right inline"></span></a>
#                             </p>
#
#             <div class="saved-jobs pull-left" data-id="4458206">
#             <span class="glyphicon glyphicon-heart remove-archive"></span>
#             <span class="saved-vacancy">В <a href="/ru/jobseeker/my/saved-jobs/" class="saved-jobs-lnk" target="_blank">сохраненных</a></span>
#             <a href="/ru/jobseeker/my/saved-jobs/?action=add&id=4458206" rel="nofollow">
#                 <span class="glyphicon glyphicon-white-heart"></span>
#                 <span class="no-saved-vacancy text-blue">Сохранить</span>
#             </a>
#         </div>
#         <div class="pull-right">
#
#                     <span class="label label-hot">Горячая</span>
#             </div>
#     <div class="clearfix"></div>
#
#             <div class="alert alert-warning add-top cut-bottom hidden" id="not-logged-in_4458206">
#             <p>Чтобы сохранить вакансию, нужно <a href="/ru/jobseeker/login/">войти</a> или <a href="/ru/jobseeker/register/">зарегистрироваться</a>.</p>
#         </div>
#     </div>
#
#
#
#
#
# <script>
# document.addEventListener("DOMContentLoaded", function()
# {
#     $(document).on('click', '#pollButton', function() {
#         var answerIds = [];
#         $('input[name="optionsR"]:checked').each(function ()
#         {
#             answerIds.push($(this).val());
#         });
#
#         if (answerIds.length > 0)
#         {
#             $.ajax({
#                 method: "POST",
#                 url: "/_data/_ajax/process_poll.php",
#                 data: {questId: $('#questId').val(), answerId: answerIds, questFor: $('#questFor').val()},
#                 success: function (data)
#                 {
#                     data = $.parseJSON(data);
#
#                     if (data.status)
#                     {
#                         $('#poll_form').html(data.html);
#                     }
#                     else
#                     {
#                         $('#poll_form').parent('.form-group').removeClass('has-danger');
#                         $('#poll_form .text-danger').addClass('hide');
#                     }
#                 }
#             })
#         }
#         else
#         {
#             $('#poll_form').parent('.form-group').addClass('has-danger');
#             $('#poll_form .text-danger').removeClass('hide');
#         }
#
#         return false;
#     });
# });
# </script>
#
# <a name="4458170"></a>
# <div class="card card-hover card-visited wordwrap job-link js-hot-block">
#
#
#
# <img width="100" height="50" alt="Марафон, магазин"
#  class="preview-img preview-img-logo"
#  src="https://i.work.ua/employer_design/0/3/7/85037_company_logo_1.png">
#
# <h2 class="">
# <a href="/ru/jobs/4458170/" title="Продавец-консультант (ТРЦ City Center), вакансия от 20 июля 2021">Продавец-консультант (ТРЦ City Center)</a>
# </h2>
#             <div>
#                             <b>9&#8239;000&thinsp;–&thinsp;19&#8239;000&nbsp;грн</b></div>
#
# <div class="add-top-xs">
#
# <span><b>Марафон, магазин</b></span><span class="nowrap">&#32;<span
#                         data-content="Подлинность компании подтверждена Work.ua. <a href='/help/177/' class='bp-more' target='_blank'>Подробнее<span class='glyphicon glyphicon-chevron-right'></span></a>"
#                         data-toggle="popover"><span class="glyphicon glyphicon-confirmed text-blue-light"></span></span>&#32;<span>·</span></span>&#32;<span>Одесса</span>&nbsp;<span class="text-muted">&middot;</span>&#32;<span class="distance-block unclickable-inner-block border-dashed-grey
# "
# ><span
# data-content="
# Это расстояние на карте по прямой от центра города до места работы. <br/><a
# href='/jobs-odesa/'
# data-config-city='46'
# onclick='Addresses.showPopupWithChoosingAddress(this);return false;'
# class='bp-more nowrap'>Указать свой адрес<span class='glyphicon glyphicon-chevron-right'></span></a>"
# data-toggle="popover"
# data-original-title=""
# title=""
# >7,4&nbsp;км&nbsp;от&nbsp;центра</span></span></div>
#
#     <p class="overflow text-muted add-top-sm add-bottom">
#             Полная занятость.<br>
#                             Торговая сеть «Марафон» основана в 1998 году. Компания входит в ТОП 5 ритейлеров Украины в категории&hellip;&#8288;<a href="/ru/jobs/4458170/" class="no-decoration"><span class="glyphicon glyphicon-chevron-right inline"></span></a>
#                             </p>
#
#             <div class="saved-jobs pull-left" data-id="4458170">
#             <span class="glyphicon glyphicon-heart remove-archive"></span>
#             <span class="saved-vacancy">В <a href="/ru/jobseeker/my/saved-jobs/" class="saved-jobs-lnk" target="_blank">сохраненных</a></span>
#             <a href="/ru/jobseeker/my/saved-jobs/?action=add&id=4458170" rel="nofollow">
#                 <span class="glyphicon glyphicon-white-heart"></span>
#                 <span class="no-saved-vacancy text-blue">Сохранить</span>
#             </a>
#         </div>
#         <div class="pull-right">
#                                             <span class="label label-response" data-toggle="popover"
#   data-content="На эту вакансию можно откликнуться без резюме. <a class='nowrap' target='_blank'
#   href='/help/206/'>Подробнее<span class='glyphicon glyphicon-chevron-right'></span></a>"><span class="glyphicon glyphicon-lightning-full"></span><span class="response-without-resume-text">Отклик без резюме</span></span>
#                     <span class="label label-hot">Горячая</span>
#             </div>
#     <div class="clearfix"></div>
#
#             <div class="alert alert-warning add-top cut-bottom hidden" id="not-logged-in_4458170">
#             <p>Чтобы сохранить вакансию, нужно <a href="/ru/jobseeker/login/">войти</a> или <a href="/ru/jobseeker/register/">зарегистрироваться</a>.</p>
#         </div>
#     </div>
#
#
#
#
#
#
#
# <a name="3980867"></a>
# <div class="card card-hover card-visited wordwrap job-link js-hot-block">
#
#
#
# <img width="100" height="50" alt="Прайм, call-центр"
#  class="preview-img preview-img-logo"
#  src="https://i.work.ua/employer_design/5/5/0/1851550_company_logo_1.png">
#
# <h2 class="">
# <a href="/ru/jobs/3980867/" title="Оператор call-центра, вакансия от 20 июля 2021">Оператор call-центра</a>
# </h2>
#             <div>
#                             <b>10&#8239;000&thinsp;–&thinsp;20&#8239;000&nbsp;грн</b>&nbsp;<span class="text-muted">·</span>&#32;<span class="text-muted">Еженедельные выплаты</span></div>
#
# <div class="add-top-xs">
#
# <span><b>Прайм, call-центр</b></span>&nbsp;<span>·</span>&#32;<span>Одесса</span>&#32;</div>
#
#     <p class="overflow text-muted add-top-sm add-bottom">
#             Полная занятость, готовы взять студента, готовы взять человека с инвалидностью. Опыт работы от 1 года.<br>
#                             Привет! Мы та самая компания, которая в период карантина выросла в три раза. В данный момент, мы продолжаем&hellip;&#8288;<a href="/ru/jobs/3980867/" class="no-decoration"><span class="glyphicon glyphicon-chevron-right inline"></span></a>
#                             </p>
#
#             <div class="saved-jobs pull-left" data-id="3980867">
#             <span class="glyphicon glyphicon-heart remove-archive"></span>
#             <span class="saved-vacancy">В <a href="/ru/jobseeker/my/saved-jobs/" class="saved-jobs-lnk" target="_blank">сохраненных</a></span>
#             <a href="/ru/jobseeker/my/saved-jobs/?action=add&id=3980867" rel="nofollow">
#                 <span class="glyphicon glyphicon-white-heart"></span>
#                 <span class="no-saved-vacancy text-blue">Сохранить</span>
#             </a>
#         </div>
#         <div class="pull-right">
#
#                     <span class="label label-hot">Горячая</span>
#             </div>
#     <div class="clearfix"></div>
#
#             <div class="alert alert-warning add-top cut-bottom hidden" id="not-logged-in_3980867">
#             <p>Чтобы сохранить вакансию, нужно <a href="/ru/jobseeker/login/">войти</a> или <a href="/ru/jobseeker/register/">зарегистрироваться</a>.</p>
#         </div>
#     </div>
#
#
#
#
#
#
#
# <a name="4297112"></a>
# <div class="card card-hover card-visited wordwrap job-link js-hot-block">
#
#
#
# <img width="100" height="50" alt="Сільпо, мережа супермаркетів"
#  class="preview-img preview-img-logo"
#  src="https://i.work.ua/employer_design/7/5/1/21751_company_logo_3.png">
#
# <h2 class="">
# <a href="/ru/jobs/4297112/" title="Кухар, вакансия от 20 июля 2021">Кухар</a>
# </h2>
#
# <div class="add-top-xs">
#
# <span><b>Сільпо, мережа супермаркетів</b></span><span class="nowrap">&#32;<span
#                         data-content="Подлинность компании подтверждена Work.ua. <a href='/help/177/' class='bp-more' target='_blank'>Подробнее<span class='glyphicon glyphicon-chevron-right'></span></a>"
#                         data-toggle="popover"><span class="glyphicon glyphicon-confirmed text-blue-light"></span></span>&#32;<span class="text-orange">·</span></span>&#32;<span class="label-vip">VIP</span>&nbsp;<span>·</span>&#32;<span>Одесса</span>&#32;</div>
#
#     <p class="overflow text-muted add-top-sm add-bottom">
#             Полная занятость, неполная занятость, готовы взять студента. Опыт работы от 1 года.<br>
#                             Кухарі, давайте творити мистецтво смаку разом! Шукаємо в свою команду професіоналів, які не можуть вгамуватися —&hellip;&#8288;<a href="/ru/jobs/4297112/" class="no-decoration"><span class="glyphicon glyphicon-chevron-right inline"></span></a>
#                             </p>
#
#             <div class="saved-jobs pull-left" data-id="4297112">
#             <span class="glyphicon glyphicon-heart remove-archive"></span>
#             <span class="saved-vacancy">В <a href="/ru/jobseeker/my/saved-jobs/" class="saved-jobs-lnk" target="_blank">сохраненных</a></span>
#             <a href="/ru/jobseeker/my/saved-jobs/?action=add&id=4297112" rel="nofollow">
#                 <span class="glyphicon glyphicon-white-heart"></span>
#                 <span class="no-saved-vacancy text-blue">Сохранить</span>
#             </a>
#         </div>
#         <div class="pull-right">
#                                             <span class="label label-response" data-toggle="popover"
#   data-content="На эту вакансию можно откликнуться без резюме. <a class='nowrap' target='_blank'
#   href='/help/206/'>Подробнее<span class='glyphicon glyphicon-chevron-right'></span></a>"><span class="glyphicon glyphicon-lightning-full"></span><span class="response-without-resume-text">Отклик без резюме</span></span>
#                     <span class="label label-hot">Горячая</span>
#             </div>
#     <div class="clearfix"></div>
#
#             <div class="alert alert-warning add-top cut-bottom hidden" id="not-logged-in_4297112">
#             <p>Чтобы сохранить вакансию, нужно <a href="/ru/jobseeker/login/">войти</a> или <a href="/ru/jobseeker/register/">зарегистрироваться</a>.</p>
#         </div>
#     </div>
#
#
#
#
#
#
#
# <a name="4217848"></a>
# <div class="card card-hover card-visited wordwrap job-link js-hot-block">
#
#
#
# <img width="100" height="50" alt="Сільпо, мережа супермаркетів"
#  class="preview-img preview-img-logo"
#  src="https://i.work.ua/employer_design/7/5/1/21751_company_logo_3.png">
#
# <h2 class="">
# <a href="/ru/jobs/4217848/" title="Кухар з приготування суші, вакансия от 20 июля 2021">Кухар з приготування суші</a>
# </h2>
#             <div>
#                             <b>19&#8239;150&nbsp;грн</b></div>
#
# <div class="add-top-xs">
#
# <span><b>Сільпо, мережа супермаркетів</b></span><span class="nowrap">&#32;<span
#                         data-content="Подлинность компании подтверждена Work.ua. <a href='/help/177/' class='bp-more' target='_blank'>Подробнее<span class='glyphicon glyphicon-chevron-right'></span></a>"
#                         data-toggle="popover"><span class="glyphicon glyphicon-confirmed text-blue-light"></span></span>&#32;<span class="text-orange">·</span></span>&#32;<span class="label-vip">VIP</span>&nbsp;<span>·</span>&#32;<span>Одесса</span>&#32;</div>
#
#     <p class="overflow text-muted add-top-sm add-bottom">
#             Полная занятость, неполная занятость. Опыт работы от 1 года.<br>
#                             Кухарі, давайте творити мистецтво смаку разом! Шукаємо в свою команду професіоналів, які не можуть вгамуватися —&hellip;&#8288;<a href="/ru/jobs/4217848/" class="no-decoration"><span class="glyphicon glyphicon-chevron-right inline"></span></a>
#                             </p>
#
#             <div class="saved-jobs pull-left" data-id="4217848">
#             <span class="glyphicon glyphicon-heart remove-archive"></span>
#             <span class="saved-vacancy">В <a href="/ru/jobseeker/my/saved-jobs/" class="saved-jobs-lnk" target="_blank">сохраненных</a></span>
#             <a href="/ru/jobseeker/my/saved-jobs/?action=add&id=4217848" rel="nofollow">
#                 <span class="glyphicon glyphicon-white-heart"></span>
#                 <span class="no-saved-vacancy text-blue">Сохранить</span>
#             </a>
#         </div>
#         <div class="pull-right">
#                                             <span class="label label-response" data-toggle="popover"
#   data-content="На эту вакансию можно откликнуться без резюме. <a class='nowrap' target='_blank'
#   href='/help/206/'>Подробнее<span class='glyphicon glyphicon-chevron-right'></span></a>"><span class="glyphicon glyphicon-lightning-full"></span><span class="response-without-resume-text">Отклик без резюме</span></span>
#                     <span class="label label-hot">Горячая</span>
#             </div>
#     <div class="clearfix"></div>
#
#             <div class="alert alert-warning add-top cut-bottom hidden" id="not-logged-in_4217848">
#             <p>Чтобы сохранить вакансию, нужно <a href="/ru/jobseeker/login/">войти</a> или <a href="/ru/jobseeker/register/">зарегистрироваться</a>.</p>
#         </div>
#     </div>
#
#
#
#
#
#
#
# <a name="4457923"></a>
# <div class="card card-hover card-visited wordwrap job-link js-hot-block">
#
#
#
#
# <h2 class="">
# <a href="/ru/jobs/4457923/" title="Office logistics manager, вакансия от 19 июля 2021">Office logistics manager</a>
# </h2>
#             <div>
#                             <b>18&#8239;000&thinsp;–&thinsp;30&#8239;000&nbsp;грн</b></div>
#
# <div class="add-top-xs">
#
# <span><b>Terrano Financial, LLC</b></span>&nbsp;<span>·</span>&#32;<span>Одесса</span>&nbsp;<span class="text-muted">&middot;</span>&#32;<span class="distance-block unclickable-inner-block border-dashed-grey
# "
# ><span
# data-content="
# Это расстояние на карте по прямой от центра города до места работы. <br/><a
# href='/jobs-odesa/'
# data-config-city='46'
# onclick='Addresses.showPopupWithChoosingAddress(this);return false;'
# class='bp-more nowrap'>Указать свой адрес<span class='glyphicon glyphicon-chevron-right'></span></a>"
# data-toggle="popover"
# data-original-title=""
# title=""
# >4&nbsp;км&nbsp;от&nbsp;центра</span></span></div>
#
#     <p class="overflow text-muted add-top-sm add-bottom">
#             Полная занятость. Опыт работы от 1 года. Высшее образование.<br>
#                             Allstate Transport (DBA for Terrano Financial) is an American and Ukrainian affiliate based freight transport&hellip;&#8288;<a href="/ru/jobs/4457923/" class="no-decoration"><span class="glyphicon glyphicon-chevron-right inline"></span></a>
#                             </p>
#
#             <div class="saved-jobs pull-left" data-id="4457923">
#             <span class="glyphicon glyphicon-heart remove-archive"></span>
#             <span class="saved-vacancy">В <a href="/ru/jobseeker/my/saved-jobs/" class="saved-jobs-lnk" target="_blank">сохраненных</a></span>
#             <a href="/ru/jobseeker/my/saved-jobs/?action=add&id=4457923" rel="nofollow">
#                 <span class="glyphicon glyphicon-white-heart"></span>
#                 <span class="no-saved-vacancy text-blue">Сохранить</span>
#             </a>
#         </div>
#         <div class="pull-right">
#
#                     <span class="label label-hot">Горячая</span>
#             </div>
#     <div class="clearfix"></div>
#
#             <div class="alert alert-warning add-top cut-bottom hidden" id="not-logged-in_4457923">
#             <p>Чтобы сохранить вакансию, нужно <a href="/ru/jobseeker/login/">войти</a> или <a href="/ru/jobseeker/register/">зарегистрироваться</a>.</p>
#         </div>
#     </div>
#
#
#
#
#
#
#
# <a name="2170126"></a>
# <div class="card card-hover card-visited wordwrap job-link js-hot-block">
#
#
#
# <img width="100" height="50" alt="Колван А.А., ФЛП"
#  class="preview-img preview-img-logo"
#  src="https://i.work.ua/employer_design/8/3/9/574839_company_logo_1.png">
#
# <h2 class="">
# <a href="/ru/jobs/2170126/" title="Продавец-консультант в чайно-кофейный магазин, вакансия от 19 июля 2021">Продавец-консультант в чайно-кофейный магазин</a>
# </h2>
#             <div>
#                             <b>12&#8239;000&nbsp;грн</b>&nbsp;<span class="text-muted">·</span>&#32;<span class="text-muted">(Ставка+% от продаж)+премии</span></div>
#
# <div class="add-top-xs">
#
# <span><b>Колван А.А., ФЛП</b></span><span class="nowrap">&#32;<span
#                         data-content="Подлинность компании подтверждена Work.ua. <a href='/help/177/' class='bp-more' target='_blank'>Подробнее<span class='glyphicon glyphicon-chevron-right'></span></a>"
#                         data-toggle="popover"><span class="glyphicon glyphicon-confirmed text-blue-light"></span></span>&#32;<span>·</span></span>&#32;<span>Одесса</span>&#32;</div>
#
#     <p class="overflow text-muted add-top-sm add-bottom">
#             Полная занятость.<br>
#                             В крупную сеть специализированных чайно-кофейных магазинов «КУПАЖЪ» (25 магазинов в Одессе), на постоянную&hellip;&#8288;<a href="/ru/jobs/2170126/" class="no-decoration"><span class="glyphicon glyphicon-chevron-right inline"></span></a>
#                             </p>
#
#             <div class="saved-jobs pull-left" data-id="2170126">
#             <span class="glyphicon glyphicon-heart remove-archive"></span>
#             <span class="saved-vacancy">В <a href="/ru/jobseeker/my/saved-jobs/" class="saved-jobs-lnk" target="_blank">сохраненных</a></span>
#             <a href="/ru/jobseeker/my/saved-jobs/?action=add&id=2170126" rel="nofollow">
#                 <span class="glyphicon glyphicon-white-heart"></span>
#                 <span class="no-saved-vacancy text-blue">Сохранить</span>
#             </a>
#         </div>
#         <div class="pull-right">
#
#                     <span class="label label-hot">Горячая</span>
#             </div>
#     <div class="clearfix"></div>
#
#             <div class="alert alert-warning add-top cut-bottom hidden" id="not-logged-in_2170126">
#             <p>Чтобы сохранить вакансию, нужно <a href="/ru/jobseeker/login/">войти</a> или <a href="/ru/jobseeker/register/">зарегистрироваться</a>.</p>
#         </div>
#     </div>
#
# <div class="card">
# <div class="slides logotype-slides hidden-print" id="vip_logos">
# <a class="slide-left hidden-xs" href="javascript: void(0)"><span class="glyphicon glyphicon-chevron-left"></span></a>
# <a class="slide-right hidden-xs" href="javascript: void(0)"><span class="glyphicon glyphicon-chevron-right"></span></a>
# <a href="/ru/jobs/by-company/1765611/" class="item-logo" title="Работа в A-Play. Вакансии">
# <div class="item-logo-img e1765611"></div>
# </a>
# <a href="/ru/jobs/by-company/140437/" class="item-logo" title="Работа в Глобино, ГК. Вакансии">
# <div class="item-logo-img e140437"></div>
# </a>
# <a href="/ru/jobs/by-company/77932/" class="item-logo" title="Работа в АВ металл групп, ООО. Вакансии">
# <div class="item-logo-img e77932"></div>
# </a>
# <a href="/ru/jobs/by-company/47385/" class="item-logo" title="Работа в Серв&#039;є Україна. Вакансии">
# <div class="item-logo-img e47385"></div>
# </a>
# <a href="/ru/jobs/by-company/212986/" class="item-logo" title="Работа в Клуб Сімейного Дозвілля. Вакансии">
# <div class="item-logo-img e212986"></div>
# </a>
# </div>
# </div>
# <script>var vpl = {"_116340":"Полісан, виробниче підприємство, ТОВ","_353930":"Беліф","_642049":"Афіна, група компаній","_97573":"Баядера Логистик, ООО","_642330":"Аквафрост, ООО","_239049":"Долфі-Україна, ТОВ","_182498":"JTI (Japan Tobacco International)","_1171017":"Azmol British Petrochemicals","_701650":"Imperia HR","_125534":"Агропросперис","_141462":"IDS","_1329689":"BST-Group","_1822287":"Fix Line Community","_49070":"DDS+","_31326":"Щедро","_1851931":"BСompany","_708875":"Бон Буассон Беверидж","_26892":"Imperial Tobacco Ukraine","_104603":"Сімпатік Груп","_1924649":"Золотые Люди, фонд помощи, БО","_388887":"AB InBev Efes","_232903":"Дарниця, фармацевтична компанія","_31919":"Coca-Cola HBC Україна, Вірменія та Молдова","_58861":"Сигарный Дом Фортуна","_106118":"Инвитро, независимая лаборатория","_13777":"ПроКредит Банк","_850266":"А-Банк, АТ","_18864":"Корпорація «Біосфера»","_91828":"Укртелеком, АТ","_253499":"Тедіс Україна, ТОВ","_67775":"Еліт-Україна","_364535":"Gemicle","_34201":"ФМ Хладопром, ООО","_181410":"КредитМаркет","_156412":"Pro Pharma","_146007":"Кусум, группа компаний","_36257":"Агромат, ПТК, ТОВ","_53690":"Delta Medical","_71695":"Юрія-Фарм, ТОВ","_23717":"Берлин-Хеми (А.Менарини Украина ГмбХ, представительство)","_238650":"Kan Development","_1092666":"ERC","_65684":"Klion group","_419959":"Авер-Тех, ООО","_1036839":"Лайм Кепител, ООО","_48649":"Артеріум, корпорація","_13466":"Альфа-Банк Україна","_318346":"ШвидкоГрошi","_7672":"STV group","_236840":"ВиЯр","_563112":"Анри-Фарм, аптечная сеть","_392304":"Ван Колл Центр, ООО","_42788":"Датагруп","_50178":"Huawei Ukraine LLC (Хуавей Україна, ТОВ)","_85007":"ПриватБанк","_1142693":"React","_24773":"Київстар","_199876":"ТАС","_164171":"Копейка, торговая сеть","_48303":"Стандартпарк Україна","_322330":"Vitagro, група компаній","_2419":"PepsiCo Ukraine","_55507":"БаДМ, ТОВ","_201447":"Філіп Морріс Україна, ПрАТ","_91856":"EnglishDom","_126951":"Фомальгаут Полімін, ТОВ","_619760":"Атлант Будматеріали","_65331":"Ерідон, ТОВ","_9233":"Фокстрот","_1316123":"Symbol","_404959":"Тема Мода Юкрейн","_28379":"Оптима-фарм, ЛТД, CП","_454875":"Клевер Сторс","_1225592":"Justin","_40163":"Prostor","_8611":"Південний, акціонерний банк","_732590":"UPG","_14030":"Омега, ООО","_169040":"Colin's Ukraine","_1849470":"Tikkurila, color studio","_1826407":"HedgeHog","_62998":"ТС ПЛЮС (WINETIME)","_135406":"Благо","_196141":"Клиринговый дом, банк","_308764":"Евро-Азиатская служба стимулирования сбыта, ООО","_905237":"Деликат, сім'я магазинів","_286247":"Fozzy Group Логістика","_106904":"Діла, медична лабораторія","_1275466":"Pizza Day","_881854":"Би Эл Джи Микрофинанс, ООО","_296605":"Ідея Банк","_1781585":"Crazy Land, сімейний розважальний центр","_34748":"Нова пошта, ТОВ","_1295165":"Перший, ломбард, ПТ","_795937":"Укренерго, НЕК","_458937":"Ковальська, ПБГ","_166714":"Первый Украинский Международный Банк (ПУМБ)","_24784":"Костал Україна","_32072":"Львівхолод, торгово-виробнича компанія","_425098":"Мед-сервис","_1511918":"Dnipro-M","_596964":"Червоний Маркет","_10808":"Favbet","_100879":"Новус","_105402":"Eva, лінія магазинів","_57768":"Mafia, мережа ресторанів","_36502":"Metro Cash and Carry","_220656":"PitLine, ТМ","_318853":"DTEK","_1506686":"Europe Service","_44303":"WOG","_385":"АТБ, корпорация","_114235":"Reikartz Hotel Group","_1448965":"Glovo","_44218":"Фармастор","_750619":"Метинвест","_71251":"Терра Фуд","_1036647":"Аптека оптових цін","_237501":"Алло","_661686":"SupportYourApp","_56461":"Юник Трейд","_103064":"Контінентал Фармерз Груп","_230024":"АПК-Инвест","_724299":"Барком, корпорація","_842758":"Аптека АНЦ","_215918":"Венбест, ТОВ","_1320360":"Union Group","_603760":"Консалтинг про Менеджерс","_147080":"Varus","_1518":"Еко","_1444731":"JatApp","_186055":"ringoo, магазини мобільної техніки","_166004":"Dyckerhoff Cement Ukraine","_457251":"Техно Їжак","_71285":"ІДС Аква Сервіс, ТОВ","_96156":"Жжук","_68513":"Фоззи, гипермаркет","_101840":"UKRSIBBANK BNP Paribas Group"," ...
#
#
#
#
#
#
# <a name="4457666"></a>
# <div class="card card-hover card-visited wordwrap job-link js-hot-block">
#
#
#
# <img width="100" height="50" alt="Юніон Трейд Плюс, ПП"
#  class="preview-img preview-img-logo"
#  src="https://i.work.ua/employer_design/9/4/3/23943_company_logo_3.png">
#
# <h2 class="">
# <a href="/ru/jobs/4457666/" title="Водитель со своим грузовым авто (до 3 т), вакансия от 19 июля 2021">Водитель со своим грузовым авто (до 3 т)</a>
# </h2>
#             <div>
#                             <b>20&#8239;000&nbsp;грн</b>&nbsp;<span class="text-muted">·</span>&#32;<span class="text-muted">ставка+бонус от количества ТТ+ГСМ</span></div>
#
# <div class="add-top-xs">
#
# <span><b>Юніон Трейд Плюс, ПП</b></span><span class="nowrap">&#32;<span
#                         data-content="Подлинность компании подтверждена Work.ua. <a href='/help/177/' class='bp-more' target='_blank'>Подробнее<span class='glyphicon glyphicon-chevron-right'></span></a>"
#                         data-toggle="popover"><span class="glyphicon glyphicon-confirmed text-blue-light"></span></span>&#32;<span>·</span></span>&#32;<span>Одесса</span>&nbsp;<span class="text-muted">&middot;</span>&#32;<span class="distance-block unclickable-inner-block border-dashed-grey
# "
# ><span
# data-content="
# Это расстояние на карте по прямой от центра города до места работы. <br/><a
# href='/jobs-odesa/'
# data-config-city='46'
# onclick='Addresses.showPopupWithChoosingAddress(this);return false;'
# class='bp-more nowrap'>Указать свой адрес<span class='glyphicon glyphicon-chevron-right'></span></a>"
# data-toggle="popover"
# data-original-title=""
# title=""
# >6,8&nbsp;км&nbsp;от&nbsp;центра</span></span></div>
#
#     <p class="overflow text-muted add-top-sm add-bottom">
#             Полная занятость. Опыт работы от 1 года.<br>
#                             Крупный продовольственный склад европейского стандарта район 6 км. Овидиопольской дороги приглашает на работу&hellip;&#8288;<a href="/ru/jobs/4457666/" class="no-decoration"><span class="glyphicon glyphicon-chevron-right inline"></span></a>
#                             </p>
#
#             <div class="saved-jobs pull-left" data-id="4457666">
#             <span class="glyphicon glyphicon-heart remove-archive"></span>
#             <span class="saved-vacancy">В <a href="/ru/jobseeker/my/saved-jobs/" class="saved-jobs-lnk" target="_blank">сохраненных</a></span>
#             <a href="/ru/jobseeker/my/saved-jobs/?action=add&id=4457666" rel="nofollow">
#                 <span class="glyphicon glyphicon-white-heart"></span>
#                 <span class="no-saved-vacancy text-blue">Сохранить</span>
#             </a>
#         </div>
#         <div class="pull-right">
#
#                     <span class="label label-hot">Горячая</span>
#             </div>
#     <div class="clearfix"></div>
#
#             <div class="alert alert-warning add-top cut-bottom hidden" id="not-logged-in_4457666">
#             <p>Чтобы сохранить вакансию, нужно <a href="/ru/jobseeker/login/">войти</a> или <a href="/ru/jobseeker/register/">зарегистрироваться</a>.</p>
#         </div>
#     </div>
#
#
#
#
#
#
#
# <a name="4296281"></a>
# <div class="card card-hover card-visited wordwrap job-link js-hot-block">
#
#
#
# <img width="100" height="50" alt="Poster"
#  class="preview-img preview-img-logo"
#  src="https://i.work.ua/employer_design/2/3/6/544236_company_logo_2.png">
#
# <h2 class="">
# <a href="/ru/jobs/4296281/" title="Customer support manager (IT), вакансия от 19 июля 2021">Customer support manager (IT)</a>
# </h2>
#             <div>
#             <span class="text-muted">11000-13000 грн. в зависимости от KPI</span></div>
#
# <div class="add-top-xs">
#
# <span><b>Poster</b></span><span class="nowrap">&#32;<span
#                         data-content="Подлинность компании подтверждена Work.ua. <a href='/help/177/' class='bp-more' target='_blank'>Подробнее<span class='glyphicon glyphicon-chevron-right'></span></a>"
#                         data-toggle="popover"><span class="glyphicon glyphicon-confirmed text-blue-light"></span></span>&#32;<span>·</span></span>&#32;<span>Одесса</span>&#32;</div>
#
#     <p class="overflow text-muted add-top-sm add-bottom">
#             Полная занятость, удаленная работа, готовы взять студента. Опыт работы от 1 года.<br>
#                             В Poster мы делаем одну из лучших систем автоматизации для кафе, ресторанов, магазинов и других заведений&hellip;&#8288;<a href="/ru/jobs/4296281/" class="no-decoration"><span class="glyphicon glyphicon-chevron-right inline"></span></a>
#                             </p>
#
#             <div class="saved-jobs pull-left" data-id="4296281">
#             <span class="glyphicon glyphicon-heart remove-archive"></span>
#             <span class="saved-vacancy">В <a href="/ru/jobseeker/my/saved-jobs/" class="saved-jobs-lnk" target="_blank">сохраненных</a></span>
#             <a href="/ru/jobseeker/my/saved-jobs/?action=add&id=4296281" rel="nofollow">
#                 <span class="glyphicon glyphicon-white-heart"></span>
#                 <span class="no-saved-vacancy text-blue">Сохранить</span>
#             </a>
#         </div>
#         <div class="pull-right">
#
#                     <span class="label label-hot">Горячая</span>
#             </div>
#     <div class="clearfix"></div>
#
#             <div class="alert alert-warning add-top cut-bottom hidden" id="not-logged-in_4296281">
#             <p>Чтобы сохранить вакансию, нужно <a href="/ru/jobseeker/login/">войти</a> или <a href="/ru/jobseeker/register/">зарегистрироваться</a>.</p>
#         </div>
#     </div>
#
#
#
#
#
#
#
# <a name="4457611"></a>
# <div class="card card-hover card-visited wordwrap job-link js-hot-block">
#
#
#
# <img width="100" height="50" alt="Юніон Трейд Плюс, ПП"
#  class="preview-img preview-img-logo"
#  src="https://i.work.ua/employer_design/9/4/3/23943_company_logo_3.png">
#
# <h2 class="">
# ...
# <option value="5" >
# 10 000 грн (1900)</option>
# <option value="6" >
# 15 000 грн (3902)</option>
# <option value="7" >
# 20 000 грн (4600)</option>
# <option value="8" >
# 30 000 грн (4922)</option>
# <option value="9" >
# 50 000 грн (5006)</option>
# </select>
# </div>
#
# <div class="checkbox " id="nosalary_selection">
# <label><input type="checkbox" value="1"  >
# <span>Не указана</span> <span class="text-gray-light">2243</span></label>
# </div>
# </div>
# <hr>
# <div class="form-group">
# <label class="h5">Другое</label>
# <div class="checkbox " id="experience_selection">
# <label>
# <input type="checkbox" value="1"  >
# <span>Без опыта</span>
# <span class="text-gray-light">2122</span></label>
# </div>
# <div class="checkbox " id="student_selection">
# <label>
# <input type="checkbox" value="1"  >
# <span>Студентам</span>
# <span class="text-gray-light">1515</span></label>
# </div>
# <div class="checkbox " id="disability_selection">
# <label>
# <input type="checkbox" value="1"  >
# <span>Людям с инвалидностью</span>
# <span class="text-gray-light">553</span></label>
# </div>
# <div class="checkbox " id="noresume_selection">
# <label>
# <input type="checkbox" value="1"  >
# <span>Отклик без резюме</span>
# <span class="text-gray-light">2210</span></label>
# </div>
# </div>
# <hr>
#
# <div class="form-group" style="display:none">
# <label class="h5 add-bottom-sm">Поисковый запрос</label>
# <div class="checkbox" id="notitle_selection">
# <label>
# <input type="checkbox" value="1" >
# <span>Искать не только по заголовку</span>
# </label>
# </div>
# <div class="checkbox" id="nosynonym_selection">
# <label>
# <input type="checkbox" value="1" >
# <span>Не учитывать синонимы</span>
# </label>
# </div>
# <div class="checkbox" id="anyword_selection">
# <label>
# <input type="checkbox" value="1" >
# <span>Искать по любому из слов</span>
# </label>
# </div>
# </div>
# <hr style="display:none">
# </div>
# </div>
#
#
# <div class="card card-bottom bg-gray hidden-md hidden-lg">
# <div class="controls " id="job-found">
# <div id="filters-count-row" style="display: none;">
# <div id="filters-count" class="small pull-left text-muted">Выбрано 0 условий</div>
# <div class="small pull-right"><a id="filters-reset" href="javascript:;">Сбросить все</a></div>
# <div class="clearfix h-20"></div>
# </div>
# <button type="button" class="btn btn-default" id="filters-apply">Показать 7 тыс. вакансий</button>
# </div>
# <div class="controls hide" id="no-job-found">
# <div class="text-muted">По вашему запросу вакансий пока нет.</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form>
#
#
#
#
# <div id="city-seo-block" class="filter-switch-visibility" >
# </div>
#
# <div class="add-bottom-md" id="waitLoadSticky">
# <script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- Work.ua — сайдбар — 250х250 -->
# <ins class="adsbygoogle"
#      style="display:inline-block;width:250px;height:250px"
#      data-ad-client="ca-pub-1217289047681921"
#      data-ad-slot="9526814545"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
#
#
# </div>
#
#                             <div class="trn-info-block add-bottom-md">
# <a href="https://www.trn.ua/trainings/?search=%D0%9F%D1%80%D0%BE%D0%B4%D0%B0%D0%B6%D0%B8%2C+%D0%B7%D0%B0%D0%BA%D1%83%D0%BF%D0%BA%D0%B8&amp;category=0&amp;form=0&amp;company=0" target="_blank">
# <span>Тренинги по теме «Продажи, закупки»</span>
# </a>
# </div>
# <div id="bannerStickyPosition"></div>
# <div id="bannerSticky">
# <!-- Work.ua — сайдбар скролл — 250х250 -->
# <ins class="adsbygoogle" style="display:inline-block;width:250px;height:250px" data-ad-client="ca-pub-1217289047681921" data-ad-slot="5731217373"></ins>
# <div id="sticky"></div>
# </div>
#             </div>
# </div>
#
# <script>
# if (window.jQuery) {
# notificationSettingsModal.init('notificationSettingsModal', '180', {
# localePrefix: Work.localeService.getURLPrefix(),
# dropdownMinHeight: 117
# });
# }
# </script>
#
# </div>
# </section>
#     <footer class="footer-default hidden-print">
#                     <div class="container">
#                 <div class="row">
#                     <div class="col-sm-9 col-md-10">
#                         <div class="clearfix">
#                                                                                     <div class="pull-left no-pull-xs">
#                                 <div class="dropdown add-top-sm">
#                                     <a href="javascript:;"
#                                        class="dropdown-toggle"
#                                        role="button"
#                                        id="dropdownMenu100"
#                                        data-toggle="dropdown"
#                                        aria-expanded="true"
#                                     >
#                                         Русский<span class="glyphicon glyphicon-chevron-down glyph-indent"></span>
#                                     </a>
#                                     <ul class="dropdown-menu" role="menu" aria-labelledby="dropdownMenu100" id="langSwitcher">
#                                                                                     <li data-locale="ua"
#                                                 data-locale-active="ru"
#                                                                                             >
#                                                 <a href="https://www.work.ua/jobs-odesa/?setlp=ua&page=2">Українська</a>
#                                             </li>
#                                                                                     <li data-locale="ru"
#                                                 data-locale-active="ru"
#                                                 class="active"                                            >
#                                                 <a href="https://www.work.ua/ru/jobs-odesa/?&page=2">Русский</a>
#                                             </li>
#                                                                                     <li data-locale="en"
#                                                 data-locale-active="ru"
#                                                                                             >
#                                                 <a href="https://www.work.ua/en/jobs-odesa/?setlp=en&page=2">English</a>
#                                             </li>
#                                                                             </ul>
#                                 </div>
#                             </div>
#
#                                                         <div class="pull-right no-pull-xs">
#                                 <div class="btn-downl btn-downl-ru clearfix">
#                                     <a class="btn-apple-store pull-left" href="https://link.work.ua/footer-for-IOS/" target="_blank"></a>
#                                     <a class="btn-google-play pull-left" href="https://link.work.ua/footer/" target="_blank"></a>
#                                 </div>
#                             </div>
#                                                     </div>
#                         <ul class="list-inline menu-action">
#                                                             <li><a href="/ru/jobseeker/resources/" class="text-muted">Ресурсы</a></li>
#                                 <li>&nbsp;&middot;&nbsp;</li>
#                                 <li><a href="/ru/about-us/contact/" class="text-muted">Контакты</a></li>
#                                 <li>&nbsp;&middot;&nbsp;</li>
#                                 <li><a href="/ru/about-us/" class="text-muted">О нас</a></li>
#                                 <li>&nbsp;&middot;&nbsp;</li>
#                                 <li><a href="/ru/careers/" class="text-muted">Карьера</a></li>
#                                 <li>&nbsp;&middot;&nbsp;</li>
#                                 <li><a href="/ru/news/site/" class="text-muted">Новости Work.ua</a></li>
#                                 <li>&nbsp;&middot;&nbsp;</li>
#                                 <li><a href="/ru/help/" class="text-muted">Помощь</a></li>
#                                 <li>&nbsp;&middot;&nbsp;</li>
#                                 <li><a href="/ru/about-us/conditions/" class="text-muted">Условия использования</a></li>
#                                                     </ul>
#                     </div>
#                     <div class="col-sm-3 col-md-2">
#                         <a href="/ru/employer/" class="btn btn-supplement pull-right no-pull-xs" role="button">
#                                                             Работодателю
#                                                         <span class="glyphicon glyphicon-chevron-right"></span></a>
#                     </div>
#                 </div>
#
#                 <div class="text-muted">©&nbsp;2006–2021 Work.ua. Сайт поиска работы №1 в Украине.</div>
#
#                 <hr class="hidden-xs">
#
#                 <div class="row hidden-xs">
#                     <div class="col-sm-5 col-md-5">
#                         <div class="text-muted">Сделано в компании «<a href="https://www.reactor.com.ua/" target="_blank" class="text-danger">Реактор</a>».</div>
#                     </div>
#                     <div class="col-sm-7 col-md-7">
#                         <ul class="list-inline menu-action pull-right no-pull-xs cut-top">
#                             <li><a href="https://www.education.ua/" class="text-muted" target="_blank">Образование</a></li>
#                             <li>&nbsp;&middot;&nbsp;</li>
#                             <li><a href="https://www.trn.ua/" class="text-muted" target="_blank">Тренинги</a></li>
#                             <li>&nbsp;&middot;&nbsp;</li>
#                             <li><a href="https://www.ratatype.com/" class="text-muted" target="_blank">Typing tutor</a></li>
#                         </ul>
#                     </div>
#                 </div>
#             </div>
#                 <script>window.google_maps_key = 'AIzaSyAhJMHzw4iMVZDRtS-pyKbTFowE14sbH2E';</script>
#     </footer>
#                     <script src="//st.work.ua/js/lib/jquery-1.10.2.min.js"></script>
#                         <link href="//st.work.ua/css/bootstrap/main-min_1627048980.css" rel="stylesheet">
#         <script src="//i.work.ua/ru/js/lp_1627048981.js"></script>
#         <script src="//st.work.ua/js/work-min_1625750213.js"></script>
#
#         <link href="//i.work.ua/sprite/58b438e6825b1c9fbfd9a3d5860b7538.css" rel="stylesheet"/>
#         <script src="//st.work.ua/js/bootstrap/bootstrap-min_1614868080.js"></script>
#                 <script src="//st.work.ua/js/bootstrap/bootstrap-affix-fix-min_1614868080.js"></script>
#
#     <script src="//st.work.ua/js/jqplugin/jquery-cookie-min_1614868080.js"></script>
#
#
#     <script src="//st.work.ua/js/notifications/actions-min_1623156004.js"></script>
#         <!--[if lte IE 9]>
#     <script src="//st.work.ua/js/jqplugin/history-edge-min_1614868080.js"></script>
#     <![endif]-->
#     <script src="//st.work.ua/js/jqplugin/pjax-min_1614868080.js"></script>
#     <script src="//st.work.ua/js/address-min_1614868080.js"></script>
#     <script src="//st.work.ua/js/job/search-min_1623657031.js"></script>
#
#                 <script src="//st.work.ua/js/jobseeker/telegram-subscribe-btn-min_1623156004.js"></script>
#
#     <script>
#     var mapStaticHost = '//st.work.ua';
#
#     if (typeof dataLayer !== 'undefined') {
#         dataLayer.push({'PageNumberOfHot': '2_of_9'});
#     }
#
#     $('document').ready(function() {
#
#         $('body').jobSearch({
#             justForm: false,
#             formtype: 'jobsSearch',
#             selector: '.pagination a',
#             container: '#pjax',
#             jobListContainer: '#pjax-job-list',
#             setFocus: false
#         });
#
#         loadScript('//st.work.ua/js/bottom-min_1623849567.js', 'sj-s');
#
#         $('#search').searchBloorOnIOs();
#
#             });
#     </script>
#
#     <script src="//st.work.ua/js/jobseeker/saved-search-subscribe-block-min_1625215320.js"></script>
#         <script>
#         notificationSettingsModal.init('notificationSettingsModal', '180', {
#             localePrefix: Work.localeService.getURLPrefix(),
#             dropdownMinHeight: 117
#         });
#     </script>
#
#     <script src="//st.work.ua/js/jobseeker/auth-min_1625491441.js"></script>
#             <script>
#             var jaSearch = jQuery.extend(true, {}, jobseekerAuth);
#
#             document.addEventListener("DOMContentLoaded", function() {
#                 jaSearch.init({
#                     containerId: '#js-auth-subscription-to-search',
#                     loginType: 'email',
#                     currentLogin: '',
#                     localePrefix: '/ru',
#                     callbackAfterAuth: function (login, hideAuthCallback) {
#                         var formData = {
#                             id: '',
#                             type: 'searchAgent',
#                             title: 'Одесса',
#                             keyword: '',
#                             regionId: '46',
#                             categoryId: '',
#                             companyId: '',
#                             createdContext: 'search',
#                             secret: ''
#                         };
#
#                         $.ajax({
#                             url: '/ajax/jobseeker/my/saved-search/create/',
#                             method: 'POST',
#                             data: formData,
#                             success: function (data) {
#                                 hideAuthCallback();
#
#                                 if (data.success === true) {
#                                     $('.js-subscription-success-message').html(data.successMessage);
#                                     $('.js-subscription-success-block').show();
#                                 } else {
#                                     $('.js-subscription-error-message').html(data.message);
#                                     $('.js-subscription-error-block').show();
#                                 }
#
#                                 $('.js-subscription-block').show();
#                             }
#                         });
#                     }
#                 });
#             });
#
#                         function onloadCallbackSearch() {
#                 jaSearch.initRecaptcha('recaptcha-subscription-to-search');
#             }
#             function recaptchaCallbackSearch(token) {
#                 jaSearch.setRecaptchaToken(token);
#                 jaSearch.enterLoginPrepare(false, true);
#                 return true;
#             }
#                     </script>
#
#                             <script src="https://www.google.com/recaptcha/api.js?onload=onloadCallbackSearch&render=explicit&hl=ru"
#                     async defer></script>
#
#
#         <noindex>
#
# <div style="display:none;">
#     <a rel="nofollow" id="iuaCounter" href="http://www.i.ua/" target="_blank" onclick="this.href='http://i.ua/r.php?952'" title="Rated by I.UA" class="no-hover"><noscript><img src="https://r.i.ua/s?u952&p6" border="0" width="88" height="31"></noscript></a>
#     <div id="bigmirCounter">
#         <noscript><a href="http://www.bigmir.net/" target="_blank" style="padding-right:4px"><img src="https://c.bigmir.net/?v132195&s132195&t2"
#             width="88" height="31" alt="bigmir)net TOP 100" title="bigmir)net TOP 100" border="0"></a></noscript>
#     </div>
# </div>
#
# <script src="//st.work.ua/js/site_counters-min_1614868080.js"></script>
#
# </noindex>
# <script type="text/javascript">
# (function() {
# var co = document.createElement("script"); co.type = "text/javascript"; co.async = true;
# cntrs = window.cntrs || [];
# var params = "";
# for (var i = 0, l = cntrs.length; i < l; i++) {
# params = params + "&b["+(100+i)+"]="+cntrs[i][0];
# if (cntrs[i][1] != undefined) params = params + "&nc["+(100+i)+"]=1";
# if (cntrs[i][2] != undefined) params = params + "&uc["+(100+i)+"]=1";
# }
# co.src = "/_data/counter.php?b[0]=123&nc[0]=1&b[1]=770&nc[1]=1&b[2]=2198&uc[2]=1"+params+"&rnd=60fd7223013b8";
# var s = document.getElementsByTagName("script")[0]; s.parentNode.insertBefore(co, s);
# })();
# </script>
# </body>
# </html>

# %% [markdown]
# ### Поиск всех вакансий на странице

# %%
soup = bs(r.text, "html.parser")
vacancies_names = soup.find_all('h2', class_='')

for name in vacancies_names:
    print(name.a['title'])
# Out:
# Программист (Senior PHP), Team Lead, вакансия от 20 июля 2021
# Продавец-консультант (ТРЦ City Center), вакансия от 20 июля 2021
# Оператор call-центра, вакансия от 20 июля 2021
# Кухар, вакансия от 20 июля 2021
# Кухар з приготування суші, вакансия от 20 июля 2021
# Office logistics manager, вакансия от 19 июля 2021
# Продавец-консультант в чайно-кофейный магазин, вакансия от 19 июля 2021
# Водитель со своим грузовым авто (до 3 т), вакансия от 19 июля 2021
# Customer support manager (IT), вакансия от 19 июля 2021
# Водитель со своим грузовым авто (реф, до 3 т), вакансия от 19 июля 2021
# Экспедитор, вакансия от 19 июля 2021
# Менеджер по работе с клиентами (English, Deutsch, Espanol, Italiano), вакансия от 19 июля 2021
# Менеджер по продажам, вакансия от 19 июля 2021
# Менеджер по работе с клиентами, вакансия от 19 июля 2021
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-75eab1c8ec8a> in <module>
#       2 vacancies_names = soup.find_all('h2', class_='')
#       3 for name in vacancies_names:
# ----> 4     print(name.a['title'])
#
# TypeError: 'NoneType' object is not subscriptable
